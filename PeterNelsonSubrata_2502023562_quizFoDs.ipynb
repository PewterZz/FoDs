# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import sklearn

# %%
dataSet = pd.read_csv("Quiz_Dataset.csv")

# %%
df = pd.DataFrame(dataSet)
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df = df.drop("Unnamed: 0", axis= 1)
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
print(df.head())
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1       typical     145   233    1        2    150      0      2.3
# 1   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 2   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 3   37    1    nonanginal     130   250    0        0    187      0      3.5
# 4   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 0      3  0.0       fixed   No
# 1      2  3.0      normal  Yes
# 2      2  2.0  reversable  Yes
# 3      3  0.0      normal   No
# 4      1  0.0      normal   No

# %%
print(df.tail())
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 298      1.2      2  0.0  reversable  Yes
# 299      3.4      2  2.0  reversable  Yes
# 300      1.2      2  1.0  reversable  Yes
# 301      0.0      2  1.0      normal  Yes
# 302      0.0      1  NaN      normal   No

# %%
print(df.describe())
# Out:
#               Age         Sex      RestBP        Chol         Fbs     RestECG  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868  131.689769  246.693069    0.148515    0.990099
# std      9.038662    0.467299   17.599748   51.776918    0.356198    0.994971
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     48.000000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     56.000000    1.000000  130.000000  241.000000    0.000000    1.000000
# 75%     61.000000    1.000000  140.000000  275.000000    0.000000    2.000000
# max     77.000000    1.000000  200.000000  564.000000    1.000000    2.000000
#
#             MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  299.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.672241
# std     22.875003    0.469794    1.161075    0.616226    0.937438
# ...

# %%
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
#297 columns are left
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           0
# Thal         0
# AHD          0
# dtype: int64

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
print(df['Age'].var())
# Out:
# 81.89771589771594

# %%
conditions=[(df['Age'] >= 55),(df['Age'] < 55) & (df['Age'] > 40),(df['Age'] <= 40)]
values = ['Elderly', 'Middle Aged', 'Young']
df['Group'] = np.select(conditions, values)
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 297   57    0  asymptomatic     140   241    0        0    123      1
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
#
#      Oldpeak  Slope   Ca        Thal  AHD        Group
# 0        2.3      3  0.0       fixed   No      Elderly
# ...

# %%
elderly = 0
middle = 0
young = 0

for i in df["Group"]:
    if i == 'Elderly':
        elderly += 1
    elif i == 'Middle Aged':
        middle += 1
    elif i == 'Young':
        young +=1

plt.bar('Elderly', elderly, color='red', width=0.5)
plt.bar('Middle aged', middle, color='red', width=0.5)
plt.bar('Young', young, color='red', width=0.5)
plt.show()

# %%
plt.scatter(df['Group'], df['Age'], s=1, c='red', alpha=0.2)
plt.show()

# %%
k = df['Group'] == 'Elderly'
print(k.sum())
j = df['Group'] == 'Middle Aged'
print(j.sum())
i = df['Group'] == 'Young'
print(i.sum())
# Out:
# 159
# 121
# 17

# %%
x = [(159/297)*100,(121/297)*100,(17/297)*100]
plt.pie(x, labels=['Elderly', 'Middle Aged', 'Young'], shadow=True, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x206872fd640>,
# ...
#  [Text(-0.12192204056886154, 1.0932223086012858, 'Elderly'),
#   Text(-0.07557133363727847, -1.0974010085343842, 'Middle Aged'),
#   Text(1.0822631389143376, -0.19673967100532974, 'Young')],
#  [Text(-0.06650293121937902, 0.5963030774188831, '53.5%'),
#   Text(-0.04122072743851552, -0.5985823682914821, '40.7%'),
#   Text(0.5903253484987295, -0.10731254782108894, '5.7%')])

# %%
kant = pd.get_dummies(df)

# %%
df.corr()
# Out:
#               Age       Sex    RestBP      Chol       Fbs   RestECG     MaxHR  \
# Age      1.000000 -0.092399  0.290476  0.202644  0.132062  0.149917 -0.394563
# Sex     -0.092399  1.000000 -0.066340 -0.198089  0.038850  0.033897 -0.060496
# RestBP   0.290476 -0.066340  1.000000  0.131536  0.180860  0.149242 -0.049108
# Chol     0.202644 -0.198089  0.131536  1.000000  0.012708  0.165046 -0.000075
# Fbs      0.132062  0.038850  0.180860  0.012708  1.000000  0.068831 -0.007842
# RestECG  0.149917  0.033897  0.149242  0.165046  0.068831  1.000000 -0.072290
# MaxHR   -0.394563 -0.060496 -0.049108 -0.000075 -0.007842 -0.072290  1.000000
# ExAng    0.096489  0.143581  0.066691  0.059339 -0.000893  0.081874 -0.384368
# Oldpeak  0.197123  0.106567  0.191243  0.038596  0.008311  0.113726 -0.347640
# Slope    0.159405  0.033345  0.121172 -0.009215  0.047819  0.135141 -0.389307
# Ca       0.362210  0.091925  0.097954  0.115945  0.152086  0.129021 -0.268727
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(kant)
print(scaler.transform(kant))
# Out:
# [[ 0.93618065  0.69109474  0.75038004 ...  0.93162467 -0.8291562
#   -0.24640269]
#  [ 1.3789285   0.69109474  1.59626645 ...  0.93162467 -0.8291562
#   -0.24640269]
#  [ 1.3789285   0.69109474 -0.65943064 ...  0.93162467 -0.8291562
#   -0.24640269]
#  ...
#  [ 1.48961547  0.69109474  0.69398761 ...  0.93162467 -0.8291562
#   -0.24640269]
#  [ 0.27205887  0.69109474 -0.09550637 ...  0.93162467 -0.8291562
#   -0.24640269]
#  [ 0.27205887 -1.44697961 -0.09550637 ...  0.93162467 -0.8291562
#   -0.24640269]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
X_train, X_test, y_train, y_test = train_test_split(kant,df['AHD'], random_state= 1)

svm = SVC(kernel='rbf', random_state = 1, gamma = 0.5, C = 1)
svm.fit(X_train, y_train) 
predict = svm.predict(X_test)
print(accuracy_score(y_test,predict))
# Out:
# 0.5466666666666666

# %%
from sklearn.metrics import classification_report
target_names = ['Yes','No']
print(classification_report(y_test, predict, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          Yes       0.55      1.00      0.71        41
#           No       0.00      0.00      0.00        34
#
#     accuracy                           0.55        75
#    macro avg       0.27      0.50      0.35        75
# weighted avg       0.30      0.55      0.39        75
# C:\Users\ACER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ACER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=8)
principalComponents = pca.fit_transform(X_train)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['1', '2','3','4','5','6','7','8'])
principalDf
# Out:
#               1          2          3          4         5         6  \
# 0    -18.176857  -0.208643  -2.321414   3.817401  0.432587 -0.970909
# 1    105.597427  17.027814  -6.036233  -5.620985  0.114918  1.176554
# 2      8.546997  -1.729839  -2.241385  -6.093746  0.434697 -1.345096
# 3    -14.400837 -12.657069  21.108970   0.712429  0.317143 -0.529559
# 4    -43.659932 -55.794836   5.591916 -14.061057  0.425683 -1.478925
# ..          ...        ...        ...        ...       ...       ...
# 217   11.674408  19.419833  -6.285044   0.415324  2.415908 -0.436158
# 218   -0.817462  12.432166  24.772687  11.503754 -1.960006 -1.016376
# 219   19.278471  49.292832 -18.631995  -0.347119  0.291262  1.027235
# 220   23.782309 -12.856873   2.909510  -4.039133 -1.429012  0.674876
# 221   29.249402  39.413668  11.989860  -6.790248 -0.605058 -1.021516
#
#             7         8
# 0    0.426341 -0.523373
# 1    0.568071 -0.804370
# 2    2.086738 -0.342858
# 3   -0.714306 -0.139122
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=8)
principalComponents = pca.fit_transform(X_test)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['1', '2','3','4','5','6','7','8'])
principalDf
# Out:
#             1          2          3          4         5         6         7  \
# 0   -4.855921 -16.642615  -7.314496   0.366544  1.186347  0.897641 -1.568016
# 1   36.768483  44.120923  -8.738129   6.380068 -0.130778 -0.345449 -0.657794
# 2  -70.752130  14.929270  -0.562943 -11.254335 -1.596962  0.530927  0.294286
# 3  -93.825593 -29.003248  -1.487627   5.421662 -0.773241  0.038556  0.354957
# 4   -7.893887  79.956207 -10.735635  -2.164628 -2.778893  0.376689  0.580533
# ..        ...        ...        ...        ...       ...       ...       ...
# 70 -56.476174  -8.972629  -3.945551  -5.669255  0.945411  0.602707 -1.664947
# 71  57.360064 -13.260708  22.658592 -10.129417 -1.238343  0.214138  1.177706
# 72 -43.635108   2.510620 -24.285790   3.825600  1.723917  0.818090 -1.408550
# 73  33.763529 -24.622190   3.320872 -11.147892  1.066480 -0.007635 -0.855989
# 74 -14.775822 -27.236934  -9.455882  -7.493504 -0.371674  1.295170  0.434127
#
#            8
# 0  -0.473379
# 1   1.678682
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
cross_val_score(clf, iris.data, iris.target, cv=10)
